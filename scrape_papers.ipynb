# %%
import json
import re
import os
from collections import defaultdict
from datetime import datetime

# Create a logs folder to store papers
def sanitize_filename(filename, max_length=100):
    sanitized = re.sub(r'[^a-zA-Z0-9]', '_', filename)
    return sanitized[:max_length]

logs_folder_path = f'autoscious_logs/'
if not os.path.exists(logs_folder_path):
    os.makedirs(logs_folder_path)

NUM_PAPERS_TO_SCRAPE = 250

# %%
# Helper function code to get the PDF content if possible

import requests
from PyPDF2 import PdfReader 
from io import BytesIO

def try_getting_pdf(url):
    try:
        response = requests.get(url, verify=True)
        f = BytesIO(response.content)
        pdf = PdfReader(f)
        return True
    except:
        print("Could not get pdf")
        return False

# Get the PDF content
def try_getting_pdf_content(url):
    try:
        print("trying url:", url)
        response = requests.get(url, verify=True)
        f = BytesIO(response.content)
        pdf = PdfReader(f)
        content = ""

        for i in range(len(pdf.pages)):
            page = pdf.pages[i]
            text = page.extract_text()
            content += text

        print("SUCCESSSS")
        return content
    except:
        print("Error getting PDF content")
        return ""

# %%
# Load in metadata from openalex_papers.json
with open('openalex_papers.json') as f:
    open_alex_results = json.load(f)

# %%
# Scrape with selenium
from util import scrape_text_with_selenium_no_agent
MAX_RETRIES = 3

for res in open_alex_results:
    if len(os.listdir(logs_folder_path)) >= NUM_PAPERS_TO_SCRAPE:
        break

    title = res["title"]
    url = res['open_access']['oa_url'] if res['open_access']['oa_url'] else res['doi']
    full_text_path = f'autoscious_logs/{sanitize_filename(title)}.txt'
    print("title: ", title, "url: ", url)

    if title and url and not os.path.exists(full_text_path):
        print("TRYING PDF!")
        pdf_text = try_getting_pdf_content(url)
        if pdf_text:
            print("PDF WORKED!")

            # Record pdf text
            with open(full_text_path, 'w', encoding='utf-8') as f:
                f.write(pdf_text)
            print("PDF WORKED! 2")
            continue
        else:
            print("PDF DIDN'T WORK, TRYING SELENIUM")
            text = scrape_text_with_selenium_no_agent(url, None, search_engine='chrome')

            # Record pdf text
            with open(full_text_path, 'w', encoding='utf-8') as f:
                f.write(text)
# Out:
# title:  CSM-AB: graph-based antibody–antigen binding affinity prediction and docking scoring function url:  https://doi.org/10.1093/bioinformatics/btab762
# title:  ZDOCK: An initial‐stage protein‐docking algorithm url:  https://doi.org/10.1002/prot.10389
# title:  Updates to the Integrated Protein–Protein Interaction Benchmarks: Docking Benchmark Version 5 and Affinity Benchmark Version 2 url:  https://europepmc.org/articles/pmc4677049?pdf=render
# title:  Removal of N-Linked Glycosylation Enhances PD-L1 Detection and Predicts Anti-PD-1/PD-L1 Therapeutic Efficacy url:  http://www.cell.com/article/S1535610819302995/pdf
# title:  Practical Theoretic Guidance for the Design of Tumor-Targeting Agents url:  https://europepmc.org/articles/pmc3978464?pdf=render
# title:  Binding affinity prediction for antibody–protein antigen complexes: A machine learning analysis based on interface and surface areas url:  https://doi.org/10.1016/j.jmgm.2022.108364
# title:  Mathematical theory of cross-reactive radioimmunoassay and ligand-binding systems at equilibrium url:  https://doi.org/10.1016/0003-2697(72)90216-3
# title:  Free Energy Perturbation Calculation of Relative Binding Free Energy between Broadly Neutralizing Antibodies and the gp120 Glycoprotein of HIV-1 url:  https://doi.org/10.1016/j.jmb.2016.11.021
# title:  Quantitative Spatiotemporal Analysis of Antibody Fragment Diffusion and Endocytic Consumption in Tumor Spheroids url:  https://aacrjournals.org/cancerres/article-pdf/68/9/3334/2602591/3334.pdf
# title:  Mass Spectrometry of Human Leukocyte Antigen Class I Peptidomes Reveals Strong Effects of Protein Abundance and Turnover on Antigen Presentation url:  https://www.mcponline.org/content/mcprot/14/3/658.full.pdf
# title:  Affinity Improvement of a Therapeutic Antibody by Structure-Based Computational Design: Generation of Electrostatic Interactions in the Transition State Stabilizes the Antibody-Antigen Complex url:  https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0087099&type=printable
# title:  Antibody i-Patch prediction of the antibody binding site improves rigid local antibody-antigen docking url:  https://academic.oup.com/peds/article-pdf/26/10/621/4350229/gzt043.pdf
# title:  Applications of Immunogenomics to Cancer url:  http://www.cell.com/article/S0092867417300624/pdf
# title:  A Genecentric Human Protein Atlas for Expression Profiles Based on Antibodies url:  https://doi.org/10.1074/mcp.r800013-mcp200
# title:  Engineering an antibody with picomolar affinity to DOTA chelates of multiple radionuclides for pretargeted radioimmunotherapy and imaging url:  https://europepmc.org/articles/pmc4033581?pdf=render
# title:  An expanded benchmark for antibody-antigen docking and affinity prediction reveals insights into antibody recognition determinants url:  http://www.cell.com/article/S0969212621000058/pdf
# title:  Theoretical analysis of antibody targeting of tumor spheroids: importance of dosage for penetration, and affinity for retention. url:  None
# title:  Multi‐constraint computational design suggests that native sequences of germline antibody H3 loops are nearly optimal for conformational flexibility url:  https://europepmc.org/articles/pmc3978785?pdf=render
# title:  A Modeling and Experimental Investigation of the Effects of Antigen Density, Binding Affinity, and Antigen Expression Ratio on Bispecific Antibody Binding to Cell Surface Targets url:  https://doi.org/10.1074/jbc.m116.714287
# title:  PD-1 Blockade in Tumors with Mismatch-Repair Deficiency url:  https://www.nejm.org/doi/pdf/10.1056/NEJMoa1500596?articleTools=true
# title:  Co-optimization of therapeutic antibody affinity and specificity using machine learning models that generalize to novel mutational space url:  https://www.nature.com/articles/s41467-022-31457-3.pdf
# title:  Antibodypedia, a Portal for Sharing Antibody and Antigen Validation Data url:  http://www.mcponline.org/article/S1535947620312846/pdf
# title:  Principles that Govern the Folding of Protein Chains url:  https://doi.org/10.1126/science.181.4096.223
# title:  Quantitative explanation for increased affinity shown by mixtures of monoclonal antibodies: Importance of a circular complex url:  https://doi.org/10.1016/0161-5890(83)90025-1
# title:  The Human Plasma Proteome url:  http://www.mcponline.org/content/3/4/311.full.pdf
# title:  <i>AREA-AFFINITY</i>: A Web Server for Machine Learning-Based Prediction of Protein–Protein and Antibody–Protein Antigen Binding Affinities url:  https://pubs.acs.org/doi/pdf/10.1021/acs.jcim.2c01499
# title:  X-ray Structures of the Antigen-binding Domains from Three Variants of Humanized anti-p185HER2 Antibody 4D5 and Comparison with Molecular Modeling url:  https://doi.org/10.1006/jmbi.1993.1099
# title:  Viral protein R regulates nuclear import of the HIV-1 pre-integration complex url:  https://europepmc.org/articles/pmc1170440?pdf=render
# title:  Stress-inducible protein 1 is a cell surface ligand for cellular prion that triggers neuroprotection url:  https://onlinelibrary.wiley.com/doi/pdfdirect/10.1093/emboj/cdf325
# title:  Contribution of Antibody Hydrodynamic Size to Vitreal Clearance Revealed through Rabbit Studies Using a Species-Matched Fab url:  https://doi.org/10.1021/acs.molpharmaceut.6b00345
# title:  Quantitating Antibody Uptake In Vivo: Conditional Dependence on Antigen Expression Levels url:  https://europepmc.org/articles/pmc3000888?pdf=render
# title:  Anti-PLA2R antibodies measured by ELISA predict long-term outcome in a prevalent population of patients with idiopathic membranous nephropathy url:  http://www.kidney-international.org/article/S0085253815558316/pdf
# title:  Dose Dependence of Intratumoral Perivascular Distribution of Monoclonal Antibodies url:  https://europepmc.org/articles/pmc3971539?pdf=render
# title:  Genetic Basis for Clinical Response to CTLA-4 Blockade in Melanoma url:  https://www.nejm.org/doi/pdf/10.1056/NEJMoa1406498?articleTools=true
# title:  The cancer antigenome url:  https://europepmc.org/articles/pmc3553384?pdf=render
# title:  Oxidized Low-Density Lipoprotein and Atherosclerosis url:  https://doi.org/10.1161/atvbaha.108.179697
# title:  Prediction of protein antigenic determinants from amino acid sequences. url:  https://doi.org/10.1073/pnas.78.6.3824
# title:  Polyclonal T-Cell Responses to Cytochrome P450IID6 Are Associated With Disease Activity in Autoimmune Hepatitis Type 2 url:  http://www.gastrojournal.org/article/S0016508505025308/pdf
# title:  SARS-CoV-2 variants, spike mutations and immune escape url:  https://www.nature.com/articles/s41579-021-00573-0.pdf
# title:  Assisted Design of Antibody and Protein Therapeutics (ADAPT) url:  https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0181490&type=printable
# title:  Hic, a Novel Surface Protein of Streptococcus pneumoniae That Interferes with Complement Function url:  http://www.jbc.org/article/S002192582088644X/pdf
# title:  Biodistribution studies with tumor-targeting bispecific antibodies reveal selective accumulation at the tumor site url:  https://www.tandfonline.com/doi/pdf/10.4161/mabs.22271?needAccess=true
# title:  Germline V-genes sculpt the binding site of a family of antibodies neutralizing human cytomegalovirus url:  https://europepmc.org/articles/pmc2567409?pdf=render
# title:  Dendritic Cells as Vectors for Therapy url:  http://www.cell.com/article/S0092867401004482/pdf
# title:  Modeling the structure of mAb 14B7 bound to the anthrax protective antigen url:  https://doi.org/10.1002/prot.21595
# title:  Mac-2 binding protein is a cell-adhesive protein of the extracellular matrix which self-assembles into ring-like structures and binds beta 1 integrins, collagens and fibronectin url:  https://europepmc.org/articles/pmc1170508?pdf=render
# title:  Affinity Proteomics for Systematic Protein Profiling of Chromosome 21 Gene Products in Human Tissues url:  http://www.mcponline.org/article/S1535947620344546/pdf
# title:  Behavior of ligand binding assays with crowded surfaces: Molecular model of antigen capture by antibody-conjugated nanoparticles url:  https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0185518&type=printable
# title:  Biochemical Evidence for the Co-association of Three N-Methyl-d-aspartate (NMDA) R2 Subunits in Recombinant NMDA Receptors url:  http://www.jbc.org/article/S0021925819551456/pdf
# title:  Application of Assisted Design of Antibody and Protein Therapeutics (ADAPT) improves efficacy of a Clostridium difficile toxin A single-domain antibody url:  https://www.nature.com/articles/s41598-018-20599-4.pdf
# title:  Identification of T-helper and linear B epitope in the hypervariable region of nucleocapsid protein of PPRV and its use in the development of specific antibodies to detect viral antigen url:  https://doi.org/10.1016/j.vetmic.2006.07.023
# title:  Dissecting FcγR Regulation through a Multivalent Binding Model url:  http://www.cell.com/article/S2405471218302369/pdf
# title:  Effect of bivalent interaction upon apparent antibody affinity: experimental confirmation of theory using fluorescence photobleaching and implications for antibody binding assays. url:  None
# title:  Affinity ranking of antibodies using flow cytometry: Application in antibody phage display-based target discovery url:  https://doi.org/10.1016/j.jim.2005.04.016
# TRYING PDF!
# trying url: https://doi.org/10.1016/j.jim.2005.04.016
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1016/j.jim.2005.04.016
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  ! There was a problem providing the content you requested
# Please contact us via our
# support center for more information and provide the details below.
# Reference Number: 83edfbfb5df4197c
# IP Address: 108.46.77.125
# Timestamp: 2024-01-01 21:51:34 UTC
# ::CLOUDFLARE_ERROR_1000S_BOX::
# title:  Evaluation of mutagenesis for epitope mapping. Structure of an antibody-protein antigen complex url:  https://doi.org/10.1016/s0021-9258(18)82041-5
# TRYING PDF!
# trying url: https://doi.org/10.1016/s0021-9258(18)82041-5
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1016/s0021-9258(18)82041-5
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83edfc4cbefd0caePerformance & security by Cloudflare
# title:  Macrophage-derived Chemokine Is a Functional Ligand for the CC Chemokine Receptor 4 url:  http://www.jbc.org/article/S0021925819895662/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819895662/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819895662/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83edfc92998e41f8Performance & security by Cloudflare
# title:  Fcγ receptors as regulators of immune responses url:  https://doi.org/10.1038/nri2206
# TRYING PDF!
# trying url: https://doi.org/10.1038/nri2206
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1038/nri2206
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  We use essential cookies to make sure the site can function. We also use optional cookies for advertising, personalisation of content, usage analysis, and social media.
# By accepting optional cookies, you consent to the processing of your personal data - including transfers to third parties. Some third parties are outside of the European Economic Area, with varying standards of data protection. See our privacy policy for more information on the use of your personal data.
# Manage preferences for fu
# title:  Mass Spectrometry as a Diagnostic and a Cancer Biomarker Discovery Tool url:  http://www.mcponline.org/article/S1535947620349033/pdf
# TRYING PDF!
# trying url: http://www.mcponline.org/article/S1535947620349033/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.mcponline.org/article/S1535947620349033/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.mcponline.orgChecking if the site connection is securewww.mcponline.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83edfd342c381a28Performance & security by Cloudflare
# title:  Evidence for a Mechanism of Repression of Heat Shock Factor 1 Transcriptional Activity by a Multichaperone Complex url:  http://www.jbc.org/article/S0021925819373661/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819373661/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819373661/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83edfd79bf6a41d9Performance & security by Cloudflare
# title:  The Human Protein Atlas as a proteomic resource for biomarker discovery url:  https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2796.2011.02427.x
# TRYING PDF!
# trying url: https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2796.2011.02427.x
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://onlinelibrary.wiley.com/doi/pdfdirect/10.1111/j.1365-2796.2011.02427.x
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  onlinelibrary.wiley.comChecking if the site connection is secureonlinelibrary.wiley.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83edfdcfbc2142e8Performance & security by Cloudflare
# title:  Magnitude of the Hydrophobic Effect at Central versus Peripheral Sites in Protein-Protein Interfaces url:  http://www.cell.com/article/S0969212605000298/pdf
# TRYING PDF!
# trying url: http://www.cell.com/article/S0969212605000298/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.cell.com/article/S0969212605000298/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.cell.comChecking if the site connection is securewww.cell.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83edfe1c4cf53354Performance & security by Cloudflare
# title:  Molecular Modeling and Affinity Determination of scFv Antibody: Proper Linker Peptide Enhances Its Activity url:  http://dspace.imech.ac.cn/bitstream/311007/33025/1/Molecular%20modeling%20and%20affinity%20determination.pdf
# TRYING PDF!
# trying url: http://dspace.imech.ac.cn/bitstream/311007/33025/1/Molecular%20modeling%20and%20affinity%20determination.pdf
# SUCCESSSS
# PDF WORKED!
# PDF WORKED! 2
# title:  Computational prediction of the cross‐reactive neutralizing epitope corresponding to the monoclonal antibody b12 specific for HIV‐1 gp120 url:  https://doi.org/10.1096/fj.05-5509rev
# TRYING PDF!
# trying url: https://doi.org/10.1096/fj.05-5509rev
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1096/fj.05-5509rev
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  onlinelibrary.wiley.comChecking if the site connection is secureonlinelibrary.wiley.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83edfe817f5f439cPerformance & security by Cloudflare
# title:  Mismatch repair deficiency predicts response of solid tumors to PD-1 blockade url:  https://science.sciencemag.org/content/sci/357/6349/409.full.pdf
# TRYING PDF!
# trying url: https://science.sciencemag.org/content/sci/357/6349/409.full.pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://science.sciencemag.org/content/sci/357/6349/409.full.pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.science.orgChecking if the site connection is securewww.science.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83edfed3a8c91815Performance & security by Cloudflare
# title:  Control of Regulatory T Cell Lineage Commitment and Maintenance url:  http://www.cell.com/article/S1074761309001964/pdf
# TRYING PDF!
# trying url: http://www.cell.com/article/S1074761309001964/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.cell.com/article/S1074761309001964/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.cell.comChecking if the site connection is securewww.cell.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83edff1b8bd3186dPerformance & security by Cloudflare
# title:  Methyl-CpG-binding Protein, MeCP2, Is a Target Molecule for Maintenance DNA Methyltransferase, Dnmt1 url:  http://www.jbc.org/article/S0021925819327814/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819327814/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819327814/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83edff64b8c11986Performance & security by Cloudflare
# title:  Multiscale Modeling of Functionalized Nanocarriers in Targeted Drug Delivery url:  https://europepmc.org/articles/pmc3221469?pdf=render
# TRYING PDF!
# trying url: https://europepmc.org/articles/pmc3221469?pdf=render
# SUCCESSSS
# PDF WORKED!
# PDF WORKED! 2
# title:  Prediction of VH–VL domain orientation for antibody variable domain modeling url:  https://doi.org/10.1002/prot.24756
# TRYING PDF!
# trying url: https://doi.org/10.1002/prot.24756
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1002/prot.24756
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  onlinelibrary.wiley.comChecking if the site connection is secureonlinelibrary.wiley.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83edffc809f8c32ePerformance & security by Cloudflare
# title:  Quantifying the Effects of Molecular Orientation and Length on Two-dimensional Receptor-Ligand Binding Kinetics url:  http://www.jbc.org/article/S0021925819709466/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819709466/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819709466/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee0012df5d5e7dPerformance & security by Cloudflare
# title:  Immune pathomechanism of drug hypersensitivity reactions url:  https://doi.org/10.1016/j.jaci.2010.11.048
# TRYING PDF!
# trying url: https://doi.org/10.1016/j.jaci.2010.11.048
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1016/j.jaci.2010.11.048
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  secure.jbs.elsevierhealth.comChecking if the site connection is securesecure.jbs.elsevierhealth.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee0072de9f5e86Performance & security by Cloudflare
# title:  Clinical Pharmacology and Translational Aspects of Bispecific Antibodies url:  https://ascpt.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/cts.12459
# TRYING PDF!
# trying url: https://ascpt.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/cts.12459
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://ascpt.onlinelibrary.wiley.com/doi/pdfdirect/10.1111/cts.12459
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  ascpt.onlinelibrary.wiley.comChecking if the site connection is secureascpt.onlinelibrary.wiley.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee00bc6c3a7280Performance & security by Cloudflare
# title:  Translational Inhibition in Vitro of Human Papillomavirus Type 16 L2 mRNA Mediated through Interaction with Heterogenous Ribonucleoprotein K and Poly(rC)-binding Proteins 1 and 2 url:  http://www.jbc.org/article/S0021925818487716/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925818487716/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925818487716/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee0106dd6c4237Performance & security by Cloudflare
# title:  Insulin Binds to Glucagon Forming a Complex that is Hyper-Antigenic and Inducing Complementary Antibodies Having an Idiotype-Antiidiotype Relationship url:  https://doi.org/10.3109/08916930109008044
# TRYING PDF!
# trying url: https://doi.org/10.3109/08916930109008044
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.3109/08916930109008044
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.tandfonline.comChecking if the site connection is securewww.tandfonline.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee01533c537288Performance & security by Cloudflare
# title:  Novel Structural Parameters of Ig–Ag Complexes Yield a Quantitative Description of Interaction Specificity and Binding Affinity url:  https://www.frontiersin.org/articles/10.3389/fimmu.2017.00034/pdf
# TRYING PDF!
# trying url: https://www.frontiersin.org/articles/10.3389/fimmu.2017.00034/pdf
# SUCCESSSS
# PDF WORKED!
# PDF WORKED! 2
# title:  The M1 and M2 paradigm of macrophage activation: time for reassessment url:  https://f1000.com/prime/reports/b/6/13/pdf
# TRYING PDF!
# trying url: https://f1000.com/prime/reports/b/6/13/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://f1000.com/prime/reports/b/6/13/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  You don’t have access to this part of the site
# Please double-check you are signed in and try again.
# If you still cannot access and think that you should be able to do so,
# please contact us at:
# info@facultyopinions.com
# We apologize for any inconvenience caused.
# title:  Structural and Molecular Interactions of CCR5 Inhibitors with CCR5 url:  http://www.jbc.org/article/S0021925819466003/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819466003/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819466003/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee020ddb5a4246Performance & security by Cloudflare
# title:  Gene regulation by steroid hormones url:  https://doi.org/10.1016/0092-8674(89)90237-7
# TRYING PDF!
# trying url: https://doi.org/10.1016/0092-8674(89)90237-7
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1016/0092-8674(89)90237-7
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  Enable JavaScript and cookies to continue
# title:  Bicalutamide Functions as an Androgen Receptor Antagonist by Assembly of a Transcriptionally Inactive Receptor url:  http://www.jbc.org/article/S0021925819663763/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819663763/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819663763/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee02a2df0f195dPerformance & security by Cloudflare
# title:  Molecular Characterization of an Interleukin-4-inducing Factor from Schistosoma mansoni Eggs url:  http://www.jbc.org/article/S0021925819549419/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819549419/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819549419/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee02e84a160f68Performance & security by Cloudflare
# title:  Mouse Sir2 Homolog SIRT6 Is a Nuclear ADP-ribosyltransferase url:  http://www.jbc.org/article/S0021925820615721/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925820615721/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925820615721/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee03308c370f5bPerformance & security by Cloudflare
# title:  Assembly requirements of PU.1–Pip (IRF-4) activator complexes: inhibiting function in vivo using fused dimers url:  https://europepmc.org/articles/pmc1171190?pdf=render
# TRYING PDF!
# trying url: https://europepmc.org/articles/pmc1171190?pdf=render
# SUCCESSSS
# PDF WORKED!
# PDF WORKED! 2
# title:  IgA Nephropathy url:  https://doi.org/10.1681/asn.2005020134
# TRYING PDF!
# trying url: https://doi.org/10.1681/asn.2005020134
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1681/asn.2005020134
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  IgA Nephropathy : Journal of the American Society of Nephrology
# You may be trying to access this site from a secured browser on the server. Please enable scripts and reload this page.
# ASN Publications
# CJASN
# JASN
# Kidney360
# Visit our other sites
# ASN Publications
# CJASN
# JASN
# Kidney360
# ASN Publications
# CJASN
# JASN
# Kidney360
# July 2005 - Volume 16 - Issue 7
# Previous
# Article
# Next
# Article
# OutlineEpidemiology and Clinical FeaturesPathologyPathogenesisIgA and IgA Production in IgANMolecular Characteristics
# title:  A Novel Protease-docking Function of Integrin at Invadopodia url:  http://www.jbc.org/article/S0021925819554370/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819554370/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819554370/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee03f5db9f1839Performance & security by Cloudflare
# title:  Confusing signals: Recent progress in CTLA-4 biology url:  http://www.cell.com/article/S1471490614002269/pdf
# TRYING PDF!
# trying url: http://www.cell.com/article/S1471490614002269/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.cell.com/article/S1471490614002269/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.cell.comChecking if the site connection is securewww.cell.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee04444c0d0fa0Performance & security by Cloudflare
# title:  MHC Restriction in Three Dimensions: A View of T Cell Receptor/Ligand Interactions url:  http://www.cell.com/article/S0092867400801956/pdf
# TRYING PDF!
# trying url: http://www.cell.com/article/S0092867400801956/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.cell.com/article/S0092867400801956/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.cell.comChecking if the site connection is securewww.cell.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee0487ebfec44dPerformance & security by Cloudflare
# title:  Presentation of the Goodpasture Autoantigen to CD4 T Cells Is Influenced More by Processing Constraints Than by HLA Class II Peptide Binding Preferences url:  https://doi.org/10.1074/jbc.273.19.11440
# TRYING PDF!
# trying url: https://doi.org/10.1074/jbc.273.19.11440
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1074/jbc.273.19.11440
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee04d999d341f8Performance & security by Cloudflare
# title:  Structure of an HIV gp120 envelope glycoprotein in complex with the CD4 receptor and a neutralizing human antibody url:  https://europepmc.org/articles/pmc5629912?pdf=render
# TRYING PDF!
# trying url: https://europepmc.org/articles/pmc5629912?pdf=render
# SUCCESSSS
# PDF WORKED!
# PDF WORKED! 2
# title:  Application of PBPK modeling to predict monoclonal antibody disposition in plasma and tissues in mouse models of human colorectal cancer url:  https://europepmc.org/articles/pmc3727051?pdf=render
# TRYING PDF!
# trying url: https://europepmc.org/articles/pmc3727051?pdf=render
# SUCCESSSS
# PDF WORKED!
# PDF WORKED! 2
# title:  T‐cell responses in two unrelated hemophilia A inhibitor subjects include an epitope at the factor VIII R593C missense site url:  http://www.jthjournal.org/article/S1538783622075912/pdf
# TRYING PDF!
# trying url: http://www.jthjournal.org/article/S1538783622075912/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jthjournal.org/article/S1538783622075912/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  secure.jbs.elsevierhealth.comChecking if the site connection is securesecure.jbs.elsevierhealth.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee055fdc8fc402Performance & security by Cloudflare
# title:  SH2 domains recognize specific phosphopeptide sequences url:  https://doi.org/10.1016/0092-8674(93)90404-e
# TRYING PDF!
# trying url: https://doi.org/10.1016/0092-8674(93)90404-e
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1016/0092-8674(93)90404-e
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  Enable JavaScript and cookies to continue
# title:  Exploring Antibody Recognition of Sequence Space through Random-Sequence Peptide Microarrays url:  https://doi.org/10.1074/mcp.m110.000786
# TRYING PDF!
# trying url: https://doi.org/10.1074/mcp.m110.000786
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1074/mcp.m110.000786
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.mcponline.orgChecking if the site connection is securewww.mcponline.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee05fcfe091a30Performance & security by Cloudflare
# title:  The Small Ubiquitin-like Modifier (SUMO) Protein Modification System in Arabidopsis url:  http://www.jbc.org/article/S0021925819326109/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819326109/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819326109/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee063f5a6f1a07Performance & security by Cloudflare
# title:  Personalized RNA mutanome vaccines mobilize poly-specific therapeutic immunity against cancer url:  https://doi.org/10.1038/nature23003
# TRYING PDF!
# trying url: https://doi.org/10.1038/nature23003
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1038/nature23003
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  We use essential cookies to make sure the site can function. We also use optional cookies for advertising, personalisation of content, usage analysis, and social media.
# By accepting optional cookies, you consent to the processing of your personal data - including transfers to third parties. Some third parties are outside of the European Economic Area, with varying standards of data protection. See our privacy policy for more information on the use of your personal data.
# Manage preferences for fu
# title:  A Major Histocompatibility Complex·Peptide-restricted Antibody and T Cell Receptor Molecules Recognize Their Target by Distinct Binding Modes url:  http://www.jbc.org/article/S0021925820763507/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925820763507/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925820763507/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee06e56a884364Performance & security by Cloudflare
# title:  A guide to cancer immunotherapy: from T cell basic science to clinical practice url:  https://www.nature.com/articles/s41577-020-0306-5.pdf
# TRYING PDF!
# trying url: https://www.nature.com/articles/s41577-020-0306-5.pdf
# SUCCESSSS
# PDF WORKED!
# PDF WORKED! 2
# title:  Regulation of Nuclear Import by Phosphorylation Adjacent to Nuclear Localization Signals url:  http://www.jbc.org/article/S0021925820669113/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925820669113/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925820669113/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee0774bb7e4385Performance & security by Cloudflare
# title:  Predicted and observed effects of antibody affinity and antigen density on monoclonal antibody uptake in solid tumors. url:  None
# title:  The biogenesis, biology and characterization of circular RNAs url:  https://doi.org/10.1038/s41576-019-0158-7
# TRYING PDF!
# trying url: https://doi.org/10.1038/s41576-019-0158-7
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1038/s41576-019-0158-7
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  We use essential cookies to make sure the site can function. We also use optional cookies for advertising, personalisation of content, usage analysis, and social media.
# By accepting optional cookies, you consent to the processing of your personal data - including transfers to third parties. Some third parties are outside of the European Economic Area, with varying standards of data protection. See our privacy policy for more information on the use of your personal data.
# Manage preferences for fu
# title:  High Density O-Glycosylation on Tandem Repeat Peptide from Secretory MUC1 of T47D Breast Cancer Cells url:  http://www.jbc.org/article/S0021925819871417/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819871417/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819871417/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee0817be514379Performance & security by Cloudflare
# title:  <i>Ab initio</i> structure prediction of the antibody hypervariable H3 loop url:  https://doi.org/10.1002/prot.24240
# TRYING PDF!
# trying url: https://doi.org/10.1002/prot.24240
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1002/prot.24240
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  onlinelibrary.wiley.comChecking if the site connection is secureonlinelibrary.wiley.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee08627bba41ecPerformance & security by Cloudflare
# title:  Targeting HIF-1 for cancer therapy url:  https://doi.org/10.1038/nrc1187
# TRYING PDF!
# trying url: https://doi.org/10.1038/nrc1187
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1038/nrc1187
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  Loading [MathJax]/jax/output/HTML-CSS/config.js
# We use essential cookies to make sure the site can function. We also use optional cookies for advertising, personalisation of content, usage analysis, and social media.
# By accepting optional cookies, you consent to the processing of your personal data - including transfers to third parties. Some third parties are outside of the European Economic Area, with varying standards of data protection. See our privacy policy for more information on the use
# title:  Predicting the sequence specificities of DNA- and RNA-binding proteins by deep learning url:  https://www.nature.com/articles/nbt.3300.pdf
# TRYING PDF!
# trying url: https://www.nature.com/articles/nbt.3300.pdf
# SUCCESSSS
# PDF WORKED!
# PDF WORKED! 2
# title:  Fragment-based computational design of antibodies targeting structured epitopes url:  https://doi.org/10.1126/sciadv.abp9540
# TRYING PDF!
# trying url: https://doi.org/10.1126/sciadv.abp9540
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1126/sciadv.abp9540
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.science.orgChecking if the site connection is securewww.science.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee094d8f1c8c48Performance & security by Cloudflare
# title:  Immunochemical studies of human erythropoietin using site-specific anti-peptide antibodies. Identification of a functional domain. url:  https://doi.org/10.1016/s0021-9258(19)75765-2
# TRYING PDF!
# trying url: https://doi.org/10.1016/s0021-9258(19)75765-2
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1016/s0021-9258(19)75765-2
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# ...
# SUCCESSSS
# PDF WORKED!
# PDF WORKED! 2
# title:  Linking the T Cell Surface Protein CD2 to the Actin-capping Protein CAPZ via CMS and CIN85 url:  http://www.jbc.org/article/S0021925820862784/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925820862784/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925820862784/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee2edafddf42e5Performance & security by Cloudflare
# title:  Characterization of the Gene Encoding the Human Kidd Blood Group/Urea Transporter Protein url:  http://www.jbc.org/article/S0021925819579030/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819579030/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819579030/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee2f1c7ac617c1Performance & security by Cloudflare
# title:  Mammalian ABC Transporters in Health and Disease url:  https://pure.uva.nl/ws/files/3499814/42885_202387y.pdf
# TRYING PDF!
# trying url: https://pure.uva.nl/ws/files/3499814/42885_202387y.pdf
# SUCCESSSS
# PDF WORKED!
# PDF WORKED! 2
# title:  Drug Transport across the Blood–Brain Barrier url:  https://journals.sagepub.com/doi/pdf/10.1038/jcbfm.2012.126
# TRYING PDF!
# trying url: https://journals.sagepub.com/doi/pdf/10.1038/jcbfm.2012.126
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://journals.sagepub.com/doi/pdf/10.1038/jcbfm.2012.126
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  journals.sagepub.comChecking if the site connection is securejournals.sagepub.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee2f6f8ebf42cePerformance & security by Cloudflare
# title:  Enhancement of α-Helicity in the HIV-1 Inhibitory Peptide DP178 Leads to an Increased Affinity for Human Monoclonal Antibody 2F5 but Does Not Elicit Neutralizing Responses in Vitro url:  http://www.jbc.org/article/S0021925819331734/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819331734/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819331734/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee2fd46a09c43bPerformance & security by Cloudflare
# title:  Pre-mRNA Processing and the CTD of RNA Polymerase II: The Tail That Wags the Dog? url:  http://www.cell.com/article/S0092867400802305/pdf
# TRYING PDF!
# trying url: http://www.cell.com/article/S0092867400802305/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.cell.com/article/S0092867400802305/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.cell.comChecking if the site connection is securewww.cell.com needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee30181e638ccdPerformance & security by Cloudflare
# title:  Functional Implications from an Unexpected Position of the 49-kDa Subunit of NADH:Ubiquinone Oxidoreductase url:  https://doi.org/10.1074/jbc.m302713200
# TRYING PDF!
# trying url: https://doi.org/10.1074/jbc.m302713200
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1074/jbc.m302713200
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee30648b93c420Performance & security by Cloudflare
# title:  Two Defective Heterozygous Luteinizing Hormone Receptors Can Rescue Hormone Action url:  http://www.jbc.org/article/S0021925819357308/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819357308/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819357308/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee30a6cf274402Performance & security by Cloudflare
# title:  Immunologic and Genetic Factors in Type 1 Diabetes url:  http://www.jbc.org/article/S0021925819716858/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819716858/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819716858/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee30ed1a8641cdPerformance & security by Cloudflare
# title:  BBK32, a Fibronectin Binding MSCRAMM from Borrelia burgdorferi, Contains a Disordered Region That Undergoes a Conformational Change on Ligand Binding url:  http://www.jbc.org/article/S0021925820726360/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925820726360/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925820726360/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee313019637288Performance & security by Cloudflare
# title:  Trastuzumab — Mechanism of Action and Use in Clinical Practice url:  https://doi.org/10.1056/nejmra043186
# TRYING PDF!
# trying url: https://doi.org/10.1056/nejmra043186
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1056/nejmra043186
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.nejm.orgChecking if the site connection is securewww.nejm.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee31749fad8c75Performance & security by Cloudflare
# title:  Molecular Characterization of a Novel Fibronectin-binding Protein of Streptococcus pyogenesStrains Isolated from Toxic Shock-like Syndrome Patients url:  http://www.jbc.org/article/S0021925819714768/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819714768/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819714768/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee31b9083fc481Performance & security by Cloudflare
# title:  Inhibitors of mammalian G1 cyclin-dependent kinases. url:  http://genesdev.cshlp.org/content/9/10/1149.full.pdf
# TRYING PDF!
# trying url: http://genesdev.cshlp.org/content/9/10/1149.full.pdf
# SUCCESSSS
# PDF WORKED!
# PDF WORKED! 2
# title:  Molecular and Structural Analysis of a Continuous Birch Profilin Epitope Defined by a Monoclonal Antibody url:  http://www.jbc.org/article/S0021925819792291/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819792291/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819792291/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee32400ec54291Performance & security by Cloudflare
# title:  Kinetic proofreading in T-cell receptor signal transduction. url:  https://doi.org/10.1073/pnas.92.11.5042
# TRYING PDF!
# trying url: https://doi.org/10.1073/pnas.92.11.5042
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1073/pnas.92.11.5042
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  pnas.orgChecking if the site connection is securepnas.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee32887f5c8cc3Performance & security by Cloudflare
# title:  Anti-Peptide Monoclonal Antibodies Generated for Immuno-Multiple Reaction Monitoring-Mass Spectrometry Assays Have a High Probability of Supporting Western blot and ELISA url:  https://www.mcponline.org/content/mcprot/14/2/382.full.pdf
# TRYING PDF!
# trying url: https://www.mcponline.org/content/mcprot/14/2/382.full.pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://www.mcponline.org/content/mcprot/14/2/382.full.pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.mcponline.orgChecking if the site connection is securewww.mcponline.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee32d16db94369Performance & security by Cloudflare
# title:  Theoretical and Experimental Comparison of Different Formats of Immunochromatographic Serodiagnostics url:  https://www.mdpi.com/1424-8220/18/1/36/pdf?version=1514196220
# TRYING PDF!
# trying url: https://www.mdpi.com/1424-8220/18/1/36/pdf?version=1514196220
# SUCCESSSS
# PDF WORKED!
# PDF WORKED! 2
# title:  Predicting immunogenic tumour mutations by combining mass spectrometry and exome sequencing url:  https://doi.org/10.1038/nature14001
# TRYING PDF!
# trying url: https://doi.org/10.1038/nature14001
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1038/nature14001
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  We use essential cookies to make sure the site can function. We also use optional cookies for advertising, personalisation of content, usage analysis, and social media.
# By accepting optional cookies, you consent to the processing of your personal data - including transfers to third parties. Some third parties are outside of the European Economic Area, with varying standards of data protection. See our privacy policy for more information on the use of your personal data.
# Manage preferences for fu
# title:  Paul Ehrlich's magic bullet concept: 100 years of progress url:  https://doi.org/10.1038/nrc2394
# TRYING PDF!
# trying url: https://doi.org/10.1038/nrc2394
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  https://doi.org/10.1038/nrc2394
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  We use essential cookies to make sure the site can function. We also use optional cookies for advertising, personalisation of content, usage analysis, and social media.
# By accepting optional cookies, you consent to the processing of your personal data - including transfers to third parties. Some third parties are outside of the European Economic Area, with varying standards of data protection. See our privacy policy for more information on the use of your personal data.
# Manage preferences for fu
# title:  Transcriptional regulation by calcium, calcineurin, and NFAT url:  http://genesdev.cshlp.org/content/17/18/2205.full.pdf
# TRYING PDF!
# trying url: http://genesdev.cshlp.org/content/17/18/2205.full.pdf
# SUCCESSSS
# PDF WORKED!
# PDF WORKED! 2
# title:  Characterization of a Novel C-type Lectin-like Gene, LSECtin url:  http://www.jbc.org/article/S0021925819754325/pdf
# TRYING PDF!
# trying url: http://www.jbc.org/article/S0021925819754325/pdf
# Error getting PDF content
# PDF DIDN'T WORK, TRYING SELENIUM
# Going through url:  http://www.jbc.org/article/S0021925819754325/pdf
# select firefox options!
# hard coding chrome
# setting up chrome driver
# Driver is getting url
# set timeout!
# Page loaded within 15 seconds
# Driver got url
# Driver has found page source
# Handing off to Beautiful Soup!
# done extractin
# Text:  www.jbc.orgChecking if the site connection is securewww.jbc.org needs to review the security of your connection before proceeding.Connection is secureProceeding...Enable JavaScript and cookies to continue
# Ray ID: 83ee34238c4f6a53Performance & security by Cloudflare
